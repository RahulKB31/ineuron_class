# %% [markdown]
# # PANDAS

# %%
#It is the most powerful library we as data scienctist use it
#http://jsonviewer.stack.hu/
#https://api.github.com/repos/pandas-dev/pandas/issues

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv")

# %%
df.head()
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#                                                  CSV  \
# ...

# %%
df.tail()
# Out:
#      Package          Item                                 Title  Rows  Cols  \
# 1733     vcd      UKSoccer                      UK Soccer Scores    25     3
# 1734     vcd  VisualAcuity  Visual Acuity in Left and Right Eyes    32     4
# 1735     vcd       VonBort      Von Bortkiewicz Horse Kicks Data   280     4
# 1736     vcd    WeldonDice                    Weldon's Dice Data    11     2
# 1737     vcd    WomenQueue                       Women in Queues    11     2
#
#       n_binary  n_character  n_factor  n_logical  n_numeric  \
# 1733         0            0         2          0          1
# 1734         1            0         3          0          1
# 1735         1            0         2          0          2
# 1736         0            0         1          0          1
# 1737         0            0         1          0          1
#
#                                                     CSV  \
# 1733  https://vincentarelbundock.github.io/Rdatasets...
# ...

# %%
df.to_csv()
# Out:
# ',Package,Item,Title,Rows,Cols,n_binary,n_character,n_factor,n_logical,n_numeric,CSV,Doc\r\n0,AER,Affairs,Fair\'s Extramarital Affairs Data,601,9,2,0,2,0,7,https://vincentarelbundock.github.io/Rdatasets/csv/AER/Affairs.csv,https://vincentarelbundock.github.io/Rdatasets/doc/AER/Affairs.html\r\n1,AER,ArgentinaCPI,Consumer Price Index in Argentina,80,2,0,0,0,0,2,https://vincentarelbundock.github.io/Rdatasets/csv/AER/ArgentinaCPI.csv,https://vincentarelbundock.github.io/Rdatasets/doc/AER/ArgentinaCPI.html\r\n2,AER,BankWages,Bank Wages,474,4,2,0,3,0,1,https://vincentarelbundock.github.io/Rdatasets/csv/AER/BankWages.csv,https://vincentarelbundock.github.io/Rdatasets/doc/AER/BankWages.html\r\n3,AER,BenderlyZwick,"Benderly and Zwick Data: Inflation, Growth and Stock Returns",31,5,0,0,0,0,5,https://vincentarelbundock.github.io/Rdatasets/csv/AER/BenderlyZwick.csv,https://vincentarelbundock.github.io/Rdatasets/doc/AER/BenderlyZwick.html\r\n4,AER,BondYield,Bond Yield Data,60,2,0,0,0,0,2,https://
# ...

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-ea8415b8a3ee> in <module>
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
df.dtypes
# Out:
# Package        object
# Item           object
# Title          object
# Rows            int64
# Cols            int64
# n_binary        int64
# n_character     int64
# n_factor        int64
# n_logical       int64
# n_numeric       int64
# CSV            object
# Doc            object
# dtype: object

# %%
df1 = pd.read_csv("C:/Users/Rahul/Desktop/abcd.csv", sep='#')

# %%
df1
# Out:
#    Code,"Access_to_basic_amenities","Occupied_private_dwellings"
# 0                             00,"None of these",5979
# 1                     01,"Cooking facilities",1512414
# 2        02,"Tap water that is safe to drink",1481133
# 3                           03,"Kitchen sink",1513830
# 4                           04,"Refrigerator",1481430
# 5                         05,"Bath or shower",1514472
# 6                                 06,"Toilet",1515042
# 7                     07,"Electricity supply",1503675
# 8                   77,"Response unidentifiable",1794
# 9                              99,"Not stated",132615
# 10                 TotalStated,"Total stated",1529901
# 11          TotalResponses,"Total responses",10527978
# 12                              Total,"Total",1664313

# %%
df1.to_csv('result1.csv',index=False,header=False,sep='#',columns=[])

# %%
df1.tail()
# Out:
#    Code,"Access_to_basic_amenities","Occupied_private_dwellings"
# 8                   77,"Response unidentifiable",1794
# 9                              99,"Not stated",132615
# 10                 TotalStated,"Total stated",1529901
# 11          TotalResponses,"Total responses",10527978
# 12                              Total,"Total",1664313

# %%
df1.columns
# Out:
# Index(['Code,"Access_to_basic_amenities","Occupied_private_dwellings"'], dtype='object')

# %%
type(df1['Access_to_basic_amenities'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Access_to_basic_amenities'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-94ea1814bb52> in <module>
# ...

# %%
type(df1[['Code']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-d92fa65cb92d> in <module>
# ----> 1 type(df1[['Code']])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ...

# %%
df1[['Access_to_basic_amenities']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-d27488133c87> in <module>
# ----> 1 df1[['Access_to_basic_amenities']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ...

# %%
pd.read_excel('C:/Users/rahul/Desktop/airline.xls')
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
df2 = pd.read_excel('C:/Users/rahul/Desktop/airline.xls')

# %%
pd.read_html('https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool')
# Out:
# [       Season   Age                                   Team  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
#  4     2012-13  23.0                                    OKC
#  5     2013-14  24.0                                    OKC
#  6     2014-15  25.0                                    OKC
#  7     2015-16  26.0                                    OKC
#  8     2016-17  27.0                                    TOT
#  9     2016-17  27.0                                    ORL
#  10    2016-17  27.0                                    TOR
#  11    2017-18  28.0                                    TOR
#  12    2018-19  29.0                                    TOR
#  13    2019-20  30.0                                    TOR
#  14    2020-21  31.0                                    LAC
# ...

# %%
df4 = pd.read_html('https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool')

# %%
type(df4)
# Out:
# list

# %%
len(df4)
# Out:
# 6

# %%
df4[0]
# Out:
#        Season   Age                                   Team  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
df4[3].to_csv('players_data.csv')

# %%
pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = """{
"name":"rahul",
"phone":879475,
"comp":"['ineuron','EY','unilever','verizon','deloitte','wipro']"
}"""

# %%
import json

# %%
s = json.loads(s)           #jsonviewer check on website

# %%
s
# Out:
# {'name': 'rahul',
#  'phone': 879475,
#  'comp': "['ineuron','EY','unilever','verizon','deloitte','wipro']"}

# %%
pd.DataFrame(s,columns=['comp'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-e2132e500266> in <module>
# ----> 1 pd.DataFrame(s,columns=['comp'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             # GH10856
#     253             # raise ValueError if only scalars in dict
# --> 254             index = extract_index(arrays[~missing])
#     255         else:
#     256             index = ensure_index(index)
#
# ...

# %%
import requests

# %%
res = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
res
# Out:
# <Response [200]>

# %%
js = res.json()

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/41825',
#   'id': 912116016,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYyMzEwNDI2',
#   'number': 41825,
#   'title': 'REF: share wrapping in MultiIndex setops',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
# ...

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/41825',
#  'id': 912116016,
#  'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYyMzEwNDI2',
#  'number': 41825,
#  'title': 'REF: share wrapping in MultiIndex setops',
#  'user': {'login': 'jbrockmendel',
#   'id': 8078968,
#   'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jbrockmendel',
#   'html_url': 'https://github.com/jbrockmendel',
# ...

# %%
js[0]['title']
# Out:
# 'REF: share wrapping in MultiIndex setops'

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# REF: share wrapping in MultiIndex setops
# REF: de-duplicate Index._intersection + MultiIndex._intersection
# BUG: MultiIndex.unique incorrect when NA value is present
# DOC: Whatsnew1.3 grammar
# BUG: wrong exception when slicing on TimedeltaIndex
# BUG: read_csv does not read double double quotes in pipe delimited txt file
# DOC/BLD: update README.md, list setuptools as dependency
# BUG: pd.util.hash_array fails on DatetimeIndex with tz specified
# DEPS: clarifying setuptools's status as a dependency
# Axis behaviour not consistent for df.interpolate for pad with `limit_area` passed.
# TYP: Numpy compatibility of definition of "array like"
# BUG:
# BUG: combine_first fails when one series is timezone-aware and the other is emtpy.
# BUG: undocumented astype("category").astype(str) type inconsistency between pandas 1.1 & 1.2
# BUG: `round()` for 5e5 ms should be `ceil()`
# BUG: Broken bool supports in pandas' quantile by NumPy's percentile behaviour change
# ...

# %%
len(js)
# Out:
# 30

# %%
pd.DataFrame(js,columns=['url','title'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
pd.DataFrame(js)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df4 = pd.DataFrame(js).head()

# %%
df4.to_csv('json_dump.csv')

# %%
js[0]['user']
# Out:
# {'login': 'jbrockmendel',
#  'id': 8078968,
#  'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jbrockmendel',
#  'html_url': 'https://github.com/jbrockmendel',
#  'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#  'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#  'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#  'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
# ...

# %%
df4 = pd.DataFrame(js).select_dtypes

# %%
for i in range(len(js)):
    print(js[i]['url'])
# Out:
# https://api.github.com/repos/pandas-dev/pandas/issues/41825
# https://api.github.com/repos/pandas-dev/pandas/issues/41824
# https://api.github.com/repos/pandas-dev/pandas/issues/41823
# https://api.github.com/repos/pandas-dev/pandas/issues/41822
# https://api.github.com/repos/pandas-dev/pandas/issues/41821
# https://api.github.com/repos/pandas-dev/pandas/issues/41819
# https://api.github.com/repos/pandas-dev/pandas/issues/41818
# https://api.github.com/repos/pandas-dev/pandas/issues/41817
# https://api.github.com/repos/pandas-dev/pandas/issues/41815
# https://api.github.com/repos/pandas-dev/pandas/issues/41813
# https://api.github.com/repos/pandas-dev/pandas/issues/41807
# https://api.github.com/repos/pandas-dev/pandas/issues/41805
# https://api.github.com/repos/pandas-dev/pandas/issues/41800
# https://api.github.com/repos/pandas-dev/pandas/issues/41797
# https://api.github.com/repos/pandas-dev/pandas/issues/41796
# https://api.github.com/repos/pandas-dev/pandas/issues/41792
# ...

# %%
json_data = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
data = pd.DataFrame.from_records(json_data['user'])
data.head()
# Out:
#           login        id               node_id  \
# 0  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 1  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 2  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3    rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 4  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/807896...
# 1  https://avatars.githubusercontent.com/u/807896...
# 2  https://avatars.githubusercontent.com/u/807896...
# 3  https://avatars.githubusercontent.com/u/455624...
# 4  https://avatars.githubusercontent.com/u/807896...
#
#                                          url                         html_url  \
# 0  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
# 1  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
# 2  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
# ...

# %%
l = []
for i in range(len(js)):
    l.append(js[i]['user'])
    
pd.DataFrame(l)
# Out:
#                login        id               node_id  \
# 0       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 1       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 2       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3         rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 4       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 5      architsingh15  15556124  MDQ6VXNlcjE1NTU2MTI0
# 6         fangchenli   7614606  MDQ6VXNlcjc2MTQ2MDY=
# 7       TheNeuralBit    675055  MDQ6VXNlcjY3NTA1NQ==
# 8         fangchenli   7614606  MDQ6VXNlcjc2MTQ2MDY=
# 9          mwaddoups  11441393  MDQ6VXNlcjExNDQxMzkz
# 10            Dr-Irv  15113894  MDQ6VXNlcjE1MTEzODk0
# 11     tlaytongoogle  11558041  MDQ6VXNlcjExNTU4MDQx
# 12          johnands   5294322  MDQ6VXNlcjUyOTQzMjI=
# 13            timlod   7346303  MDQ6VXNlcjczNDYzMDM=
# 14            zxdawn  30388627  MDQ6VXNlcjMwMzg4NjI3
# 15       HyukjinKwon   6477701  MDQ6VXNlcjY0Nzc3MDE=
# 16         lithomas1  47963215  MDQ6VXNlcjQ3OTYzMjE1
# ...

# %%
#2nd Lecture on Pandas

# %%
import pandas as pd

# %%
form_file = pd.read_csv("C:/Users/Rahul/ineuron/players_data.csv")

# %%
form_file.to_pickle("my_pickle")

# %%
pwd()
# Out:
# 'C:\\Users\\Rahul\\ineuron'

# %%
form_file
# Out:
#     Unnamed: 0     Season   Age Team   Lg  Pos      G     GS      MP     FG  \
# 0            0    2009-10  20.0  OKC  NBA   PF    6.0    0.0   153.0   20.0
# 1            1    2010-11  21.0  OKC  NBA   PF   17.0   17.0   490.0   67.0
# 2            2    2011-12  22.0  OKC  NBA   PF   20.0   20.0   569.0   84.0
# 3            3    2012-13  23.0  OKC  NBA   PF   11.0   11.0   366.0   59.0
# 4            4    2013-14  24.0  OKC  NBA   PF   17.0   17.0   581.0   87.0
# 5            5    2015-16  26.0  OKC  NBA   PF   18.0   18.0   602.0   85.0
# 6            6    2016-17  27.0  TOR  NBA   PF   10.0   10.0   307.0   60.0
# 7            7    2017-18  28.0  TOR  NBA   PF   10.0    9.0   260.0   30.0
# 8            8    2018-19  29.0  TOR  NBA    C   24.0    0.0   500.0   92.0
# 9            9    2019-20  30.0  TOR  NBA    C   11.0    0.0   251.0   63.0
# 10          10    2020-21  31.0  LAC  NBA    C    2.0    0.0    18.0    3.0
# ...

# %%
h5_data = pd.HDFStore('test.h5')

# %%
h5_data['obj1'] = form_file
# Out:
# C:\Users\Rahul\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['Season', 'Team', 'Lg', 'Pos'], dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
h5_data['obj1']
# Out:
#     Unnamed: 0     Season   Age Team   Lg  Pos      G     GS      MP     FG  \
# 0            0    2009-10  20.0  OKC  NBA   PF    6.0    0.0   153.0   20.0
# 1            1    2010-11  21.0  OKC  NBA   PF   17.0   17.0   490.0   67.0
# 2            2    2011-12  22.0  OKC  NBA   PF   20.0   20.0   569.0   84.0
# 3            3    2012-13  23.0  OKC  NBA   PF   11.0   11.0   366.0   59.0
# 4            4    2013-14  24.0  OKC  NBA   PF   17.0   17.0   581.0   87.0
# 5            5    2015-16  26.0  OKC  NBA   PF   18.0   18.0   602.0   85.0
# 6            6    2016-17  27.0  TOR  NBA   PF   10.0   10.0   307.0   60.0
# 7            7    2017-18  28.0  TOR  NBA   PF   10.0    9.0   260.0   30.0
# 8            8    2018-19  29.0  TOR  NBA    C   24.0    0.0   500.0   92.0
# 9            9    2019-20  30.0  TOR  NBA    C   11.0    0.0   251.0   63.0
# 10          10    2020-21  31.0  LAC  NBA    C    2.0    0.0    18.0    3.0
# ...

# %%
h5_data.put('obj2', form_file, format='table')

# %%
h5_data.select('obj2', where = ['index>= 10 and index<=15']) #Serde Operation 1)Serialization 2)Deserialization
# Out:
#     Unnamed: 0     Season   Age Team   Lg  Pos      G     GS      MP     FG  \
# 10          10    2020-21  31.0  LAC  NBA    C    2.0    0.0    18.0    3.0
# 11          11     Career   NaN  NaN  NBA  NaN  146.0  102.0  4097.0  650.0
# 12          12        NaN   NaN  NaN  NaN  NaN    NaN    NaN     NaN    NaN
# 13          13  6 seasons   NaN  OKC  NBA  NaN   89.0   83.0  2761.0  402.0
# 14          14  4 seasons   NaN  TOR  NBA  NaN   55.0   19.0  1318.0  245.0
# 15          15   1 season   NaN  LAC  NBA  NaN    2.0    0.0    18.0    3.0
#
#     ...    FT%    ORB    DRB    TRB    AST   STL    BLK    TOV     PF     PTS
# 10  ...  1.000    1.0    3.0    4.0    2.0   1.0    3.0    1.0    1.0    10.0
# 11  ...  0.792  275.0  680.0  955.0  109.0  61.0  292.0  139.0  448.0  1599.0
# 12  ...    NaN    NaN    NaN    NaN    NaN   NaN    NaN    NaN    NaN     NaN
# 13  ...  0.768  200.0  399.0  599.0   47.0  42.0  222.0   74.0  283.0   971.0
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df1 = df[df.dtypes[df.dtypes == 'object'].index]

# %%
df1.describe()
# Out:
#                                     Name   Sex  Ticket    Cabin Embarked
# count                                891   891     891      204      889
# unique                               891     2     681      147        3
# top     Silverthorne, Mr. Spencer Victor  male  347082  B96 B98        S
# freq                                   1   577       7        4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes == 'float64'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df[df.dtypes[df.dtypes=='float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df[['Age','Fare']]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
l = [4,5,6,7,8,9]

# %%
l[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-af148481e71f> in <module>
# ----> 1 l[9]
#
# IndexError: list index out of range

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[['Name']]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
type(df[['Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['Name'][5:10:2]
# Out:
# 5                       Moran, Mr. James
# 7         Palsson, Master. Gosta Leonard
# 9    Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df[['Ticket']][5:15]
# Out:
#        Ticket
# 5      330877
# 6       17463
# 7      349909
# 8      347742
# 9      237736
# 10    PP 9549
# 11     113783
# 12  A/5. 2151
# 13     347082
# 14     350406

# %%
sorted(df["Ticket"])
# Out:
# ['110152',
#  '110152',
#  '110152',
#  '110413',
#  '110413',
#  '110413',
#  '110465',
#  '110465',
#  '110564',
#  '110813',
#  '111240',
#  '111320',
#  '111361',
#  '111361',
#  '111369',
#  '111426',
#  '111427',
#  '111428',
#  '112050',
#  '112052',
#  '112053',
#  '112058',
#  '112059',
#  '112277',
#  '112379',
#  '113028',
#  '113043',
#  '113050',
#  '113051',
#  '113055',
#  '113056',
#  '113059',
#  '113501',
#  '113503',
#  '113505',
#  '113505',
#  '113509',
#  '113510',
#  '113514',
#  '113572',
#  '113572',
#  '113760',
#  '113760',
#  '113760',
#  '113760',
#  '113767',
#  '113773',
#  '113776',
#  '113776',
#  '113781',
#  '113781',
#  '113781',
#  '113781',
#  '113783',
#  '113784',
#  '113786',
#  '113787',
#  '113788',
#  '113789',
#  '113789',
#  '113792',
#  '113794',
#  '113796',
#  '113798',
#  '113798',
#  '113800',
#  '113803',
#  '113803',
#  '113804',
#  '113806',
#  '113806',
#  '113807',
#  '11668',
#  '11668',
#  '11751',
#  '11751',
#  '11752',
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
for i in df.columns:
    print(df[[i]])
# Out:
#      PassengerId
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ..           ...
# 886          887
# 887          888
# 888          889
# 889          890
# 890          891
#
# [891 rows x 1 columns]
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Rahul'] = 'KB'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Rahul'] = df['PassengerId']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.Categorical(df['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df['Pclass'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Pclass, Length: 891, dtype: bool

# %%
df['Cabin'].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
ser = df['Cabin'][df['Cabin'].isnull() == False]

# %%
ser.index
# Out:
# Int64Index([  1,   3,   6,  10,  11,  21,  23,  27,  31,  52,
#             ...
#             849, 853, 857, 862, 867, 871, 872, 879, 887, 889],
#            dtype='int64', length=204)

# %%
len(ser.index)
# Out:
# 204

# %%
df.iloc[ser.index]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[[1,6,5,8]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 6            7         0       1
# 5            6         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch    Ticket     Fare Cabin Embarked  Rahul  Rahul1
# 1      0  PC 17599  71.2833   C85        C      2       2
# 6      0     17463  51.8625   E46        S      7       7
# 5      0    330877   8.4583   NaN        Q      6       6
# 8      2    347742  11.1333   NaN        S      9       9

# %%
df[df['Fare'] == max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df['new_col'] = df['PassengerId'] + df['Age']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Task

# %% [raw]
# https://drive.google.com/file/d/1etGP85wJWsgqbsh3gX5oxc8dPKLMA1eT/view
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt
# https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv
# https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv
